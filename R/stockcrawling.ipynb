# %% [markdown]
# 1. KRX 에서 상장기업목록 크롤링
# http://kind.krx.co.kr/corpgeneral/corpList.do?method=download&searchType=13
# 2. KRX 크롤링된 데이터를 DB에 insert
#    table name : company_info
# 3. naver금융 크롤링 : KRX에 상장된 목록만
# 4. 3번 데이터를 DB에 insert
#    table name :  daily_price
#
# 조건 : 몇페이지를 크롤링을 할지 정함
# ------------------------------------------------
# 1. DB에서 회사명, 기간(시작~종료) 데이터를 가지고 오는
# 클래스 만들기
# 2. 1번을 기준으로 샘플 만들기
# -----------------
# 1. 딥러닝의  RNN(LSTM)으로 주가 예측하는 프로젝트 만들기
# ---------------------------
# web service
