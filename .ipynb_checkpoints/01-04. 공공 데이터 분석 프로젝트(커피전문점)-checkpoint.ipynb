# %%
# 라이브러리를 불러옵니다.
import pandas as pd
from pandas import DataFrame

# %% [markdown]
# ## 1. 데이터 불러오기

# %%
# 다운로드 받은 데이터중 일부를 열어봅니다.
data = pd.read_csv('data\강원.csv')
data.head(5)
# Out:
#      상가업소번호            상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드    상권업종중분류명  \
# 0  25033300      동그라미중고타이어  NaN         D       소매       D23   자동차/자동차용품
# 1  17174549  세인트존스호텔Ohcrab  NaN         O       숙박       O01       호텔/콘도
# 2  17174079        평창라마다호텔  NaN         O       숙박       O01       호텔/콘도
# 3  17173904    호텔탑스텐스카이라운지  NaN         O       숙박       O01       호텔/콘도
# 4  20782013           행복나눔  NaN         D       소매       D07  가정/주방/인테리어
#
#   상권업종소분류코드 상권업종소분류명 표준산업분류코드  ...                     건물관리번호      건물명  \
# 0    D23A04    타이어판매   G45211  ...  4215011100110960006010791      NaN
# 1    O01A01    호텔/콘도      NaN  ...  4215011300100010001017124  세인트존스호텔
# 2    O01A01    호텔/콘도      NaN  ...  4276038024102450036000001      NaN
# 3    O01A01    호텔/콘도      NaN  ...  4215035029100920001000002      NaN
# 4    D07A05   정수기연수기   G47320  ...  4211012000107980012030891      NaN
#
#                     도로명주소   구우편번호    신우편번호  동정보  층정보  호정보          경도  \
# 0         강원도 강릉시 가작로 270  210110  25488.0    1  NaN  NaN  128.904472
# 1         강원도 강릉시 창해로 307  210120  25467.0  NaN  NaN  NaN  128.920908
# 2    강원도 평창군 대관령면 오목길 107  232954  25342.0  NaN  NaN  NaN  128.717971
# 3  강원도 강릉시 옥계면 헌화로 455-34  210831  25633.0  NaN  NaN  NaN  129.052902
# 4         강원도 춘천시 후석로 275  200160  24282.0  NaN  NaN  NaN  127.752293
#
#           위도
# 0  37.770252
# 1  37.791299
# 2  37.660051
# 3  37.654680
# 4  37.876199
#
# [5 rows x 39 columns]

# %%
# data 폴더에 있는 모든 csv 파일을 읽어오기 위해 glob을 사용합니다.
from glob import glob

# csv 목록 불러오기
file_names = glob('data\*.csv')
print(file_names)
data = pd.DataFrame(index=range(0,0))
# pd.concat : csv파일 데이터를 이어서 합치기
for i in file_names:
    exdata=pd.read_csv(i)
    data = pd.concat([data,exdata],ignore_index = True)

data
# 모든 csv 병합하기

# reset index
# Out:
# ['data\\강원.csv', 'data\\경기.csv', 'data\\경남.csv', 'data\\경북.csv', 'data\\광주.csv', 'data\\대구.csv', 'data\\대전.csv', 'data\\부산.csv', 'data\\서울.csv', 'data\\세종.csv', 'data\\울산.csv', 'data\\인천.csv', 'data\\전남.csv', 'data\\전북.csv', 'data\\제주.csv', 'data\\충남.csv', 'data\\충북.csv']
# C:\Users\YoungMin\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (35) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#            상가업소번호            상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 0        25033300      동그라미중고타이어  NaN         D       소매       D23
# 1        17174549  세인트존스호텔Ohcrab  NaN         O       숙박       O01
# 2        17174079        평창라마다호텔  NaN         O       숙박       O01
# 3        17173904    호텔탑스텐스카이라운지  NaN         O       숙박       O01
# 4        20782013           행복나눔  NaN         D       소매       D07
# ...           ...            ...  ...       ...      ...       ...
# 2220895  23458013           코사마트  NaN         D       소매       D03
# 2220896  21982802           린지네일  NaN         F    생활서비스       F01
# 2220897  16985206     스테비아황칠토종백숙  NaN         Q       음식       Q05
# 2220898  21895009         대원사료상회  NaN         D       소매       D25
# 2220899  21895011          창현카센타  NaN         F    생활서비스       F14
#
#            상권업종중분류명 상권업종소분류코드   상권업종소분류명 표준산업분류코드  ...  \
# 0         자동차/자동차용품    D23A04      타이어판매   G45211  ...
# 1             호텔/콘도    O01A01      호텔/콘도      NaN  ...
# 2             호텔/콘도    O01A01      호텔/콘도      NaN  ...
# 3             호텔/콘도    O01A01      호텔/콘도      NaN  ...
# 4        가정/주방/인테리어    D07A05     정수기연수기   G47320  ...
# ...             ...       ...        ...      ...  ...
# 2220895       종합소매점    D03A01        편의점   G47122  ...
# 2220896     이/미용/건강    F01A02     발/네일케어   S96119  ...
# 2220897      닭/오리요리    Q05A01      삼계탕전문   I56111  ...
# 2220898       기타판매업    D25A25       사료소매   G47211  ...
# 2220899     자동차/이륜차    F14A01  자동차정비/카센타      NaN  ...
#
#                             건물관리번호      건물명                      도로명주소  \
# 0        4215011100110960006010791      NaN            강원도 강릉시 가작로 270
# 1        4215011300100010001017124  세인트존스호텔            강원도 강릉시 창해로 307
# 2        4276038024102450036000001      NaN       강원도 평창군 대관령면 오목길 107
# 3        4215035029100920001000002      NaN     강원도 강릉시 옥계면 헌화로 455-34
# 4        4211012000107980012030891      NaN            강원도 춘천시 후석로 275
# ...                            ...      ...                        ...
# 2220895  4313010300104800000001883      NaN            충청북도 충주시 성서7길 7
# 2220896  4311112500109250000041012      NaN  충청북도 청주시 상당구 호미로198번길 2-2
# 2220897  4315011200102970019002246      NaN          충청북도 제천시 하소천길 188
# 2220898  4315010900101960013024305      NaN           충청북도 제천시 용두천로 64
# 2220899  4315010900107420000000001      NaN           충청북도 제천시 내토로 476
#
#             구우편번호    신우편번호  동정보  층정보  호정보          경도         위도
# 0        210110.0  25488.0    1  NaN  NaN  128.904472  37.770252
# 1        210120.0  25467.0  NaN  NaN  NaN  128.920908  37.791299
# 2        232954.0  25342.0  NaN  NaN  NaN  128.717971  37.660051
# 3        210831.0  25633.0  NaN  NaN  NaN  129.052902  37.654680
# 4        200160.0  24282.0  NaN  NaN  NaN  127.752293  37.876199
# ...           ...      ...  ...  ...  ...         ...        ...
# 2220895  380020.0  27387.0  NaN    1  NaN  127.931611  36.969924
# 2220896  360182.0  28749.0  NaN  NaN  NaN  127.516243  36.625750
# 2220897  390230.0  27156.0  NaN  NaN  NaN  128.191648  37.154688
# 2220898  390150.0  27183.0  NaN    1  NaN  128.209076  37.134382
# 2220899  390150.0  27196.0  NaN    1  NaN  128.209747  37.128596
#
# [2220900 rows x 39 columns]

# %%
# 분석에 필요한 column을 고릅니다. ## 자유롭게 하셔도 상관없습니다.
data.columns
data.drop(['상가업소번호', '상권업종대분류코드', '상권업종중분류코드', '상권업종소분류코드','표준산업분류코드', '시도코드', '시군구코드', '행정동코드',  '법정동코드',  '지번코드', '대지구분코드', '대지구분명', '지번본번지', '지번부번지', '지번주소', '도로명코드', '도로명', '건물본번지',
       '건물부번지', '건물관리번호', '건물명', '도로명주소', '구우편번호', '신우편번호', '동정보', '층정보',
       '호정보', '경도', '위도'],axis =1,inplace = True)
data
# Out:
#                    상호명  지점명 상권업종대분류명    상권업종중분류명   상권업종소분류명           표준산업분류명  \
# 0            동그라미중고타이어  NaN       소매   자동차/자동차용품      타이어판매  자동차 타이어 및 튜브 판매업
# 1        세인트존스호텔Ohcrab  NaN       숙박       호텔/콘도      호텔/콘도               NaN
# 2              평창라마다호텔  NaN       숙박       호텔/콘도      호텔/콘도               NaN
# 3          호텔탑스텐스카이라운지  NaN       숙박       호텔/콘도      호텔/콘도               NaN
# 4                 행복나눔  NaN       소매  가정/주방/인테리어     정수기연수기          가전제품 소매업
# ...                ...  ...      ...         ...        ...               ...
# 2220895           코사마트  NaN       소매       종합소매점        편의점           체인화 편의점
# 2220896           린지네일  NaN    생활서비스     이/미용/건강     발/네일케어             기타미용업
# 2220897     스테비아황칠토종백숙  NaN       음식      닭/오리요리      삼계탕전문           한식 음식점업
# 2220898         대원사료상회  NaN       소매       기타판매업       사료소매            곡물 소매업
# 2220899          창현카센타  NaN    생활서비스     자동차/이륜차  자동차정비/카센타               NaN
#
#           시도명     시군구명    행정동명  법정동명
# 0         강원도      강릉시    포남1동   포남동
# 1         강원도      강릉시     초당동   강문동
# 2         강원도      평창군    대관령면  대관령면
# 3         강원도      강릉시     옥계면   옥계면
# 4         강원도      춘천시    후평2동   후평동
# ...       ...      ...     ...   ...
# 2220895  충청북도      충주시  성내.충인동   성서동
# 2220896  충청북도  청주시 상당구    용암1동   용정동
# 2220897  충청북도      제천시     용두동   신월동
# 2220898  충청북도      제천시     화산동   화산동
# 2220899  충청북도      제천시     화산동   화산동
#
# [2220900 rows x 10 columns]

# %%
# 메모리 낭비를 막기 위해 필요없는 변수는 제거합니다.

del file_names

# %%
data
# Out:
#                    상호명  지점명 상권업종대분류명    상권업종중분류명   상권업종소분류명           표준산업분류명  \
# 0            동그라미중고타이어  NaN       소매   자동차/자동차용품      타이어판매  자동차 타이어 및 튜브 판매업
# 1        세인트존스호텔Ohcrab  NaN       숙박       호텔/콘도      호텔/콘도               NaN
# 2              평창라마다호텔  NaN       숙박       호텔/콘도      호텔/콘도               NaN
# 3          호텔탑스텐스카이라운지  NaN       숙박       호텔/콘도      호텔/콘도               NaN
# 4                 행복나눔  NaN       소매  가정/주방/인테리어     정수기연수기          가전제품 소매업
# ...                ...  ...      ...         ...        ...               ...
# 2220895           코사마트  NaN       소매       종합소매점        편의점           체인화 편의점
# 2220896           린지네일  NaN    생활서비스     이/미용/건강     발/네일케어             기타미용업
# 2220897     스테비아황칠토종백숙  NaN       음식      닭/오리요리      삼계탕전문           한식 음식점업
# 2220898         대원사료상회  NaN       소매       기타판매업       사료소매            곡물 소매업
# 2220899          창현카센타  NaN    생활서비스     자동차/이륜차  자동차정비/카센타               NaN
#
#           시도명     시군구명    행정동명  법정동명
# 0         강원도      강릉시    포남1동   포남동
# 1         강원도      강릉시     초당동   강문동
# 2         강원도      평창군    대관령면  대관령면
# 3         강원도      강릉시     옥계면   옥계면
# 4         강원도      춘천시    후평2동   후평동
# ...       ...      ...     ...   ...
# 2220895  충청북도      충주시  성내.충인동   성서동
# 2220896  충청북도  청주시 상당구    용암1동   용정동
# 2220897  충청북도      제천시     용두동   신월동
# 2220898  충청북도      제천시     화산동   화산동
# 2220899  충청북도      제천시     화산동   화산동
#
# [2220900 rows x 10 columns]

# %% [markdown]
# ## 2. 데이터 구경하기

# %% [markdown]
# #### 전국 커피 전문점

# %%
# 카페만 뽑아냅니다.

df_coffee = data[data.상권업종중분류명 == '커피점/카페']

# index를 다시 세팅합니다.
#df_coffee.reset_index(inplace = True, drop = True)
df_coffee.index = range(len(df_coffee)) #이걸로도 reset 가능
print("전국 커피 전문점 점포 수 : ", len(df_coffee))
df_coffee.head()
# Out:
# 전국 커피 전문점 점포 수 :  108962
#         상호명     지점명 상권업종대분류명 상권업종중분류명     상권업종소분류명   표준산업분류명  시도명 시군구명 행정동명  \
# 0  키즈까페아이사랑     NaN       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  강원도  강릉시  성덕동
# 1      카페마실     NaN       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  강원도  원주시  단계동
# 2        힐링     NaN       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  강원도  원주시  단구동
# 3       드롭탑  속초엑스포점       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  강원도  속초시  조양동
# 4     SHIMS     NaN       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  강원도  원주시  행구동
#
#   법정동명
# 0  입암동
# 1  단계동
# 2  단구동
# 3  조양동
# 4  행구동

# %% [markdown]
# #### 서울내 커피 전문점

# %%
# 카페 중에 "서울"에 위치하고 있는 점포만 뽑아냅니다.
df_seoul_coffee = df_coffee[df_coffee.시도명 == '서울특별시']
df_seoul_coffee.index = range(len(df_seoul_coffee))
print('서울시 내 커피 전문점 점포 수 :', len(df_seoul_coffee))
df_seoul_coffee.head()
# Out:
# 서울시 내 커피 전문점 점포 수 : 20832
#      상호명          지점명 상권업종대분류명 상권업종중분류명     상권업종소분류명   표준산업분류명    시도명 시군구명  \
# 0    커피빈  코리아대학로대명거리점       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  서울특별시  종로구
# 1  요거프레소          쌍문점       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  서울특별시  도봉구
# 2  메머드커피          NaN       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  서울특별시  마포구
# 3  우성커피숍          NaN       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  서울특별시  양천구
# 4   카페클럽          NaN       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  서울특별시  송파구
#
#    행정동명  법정동명
# 0   혜화동  명륜4가
# 1  쌍문2동   쌍문동
# 2   서교동   서교동
# 3  신월4동   신월동
# 4  문정1동   문정동

# %% [markdown]
# #### 전국 스타벅스

# %%
# 이번엔 전국에 있는 스타벅스를 뽑아냅니다.

df_starbucks = df_coffee[df_coffee.상호명.str.contains('스타벅스')]
df_starbucks.index = range(len(df_starbucks))
print('전국 스타벅스 점포 수 :', len(df_starbucks))
df_starbucks.head()
# Out:
# 전국 스타벅스 점포 수 : 1545
#            상호명        지점명 상권업종대분류명 상권업종중분류명     상권업종소분류명   표준산업분류명  시도명 시군구명  \
# 0   스타벅스강릉안목항점     강릉안목항점       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  강원도  강릉시
# 1         스타벅스  대명델피노리조트점       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  강원도  고성군
# 2  스타벅스춘천후평DT점    춘천후평DT점       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  강원도  춘천시
# 3         스타벅스      춘천명동점       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  강원도  춘천시
# 4  스타벅스설악워터피아점    설악워터피아점       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  강원도  속초시
#
#    행정동명   법정동명
# 0   송정동    견소동
# 1   토성면    토성면
# 2  후평3동    후평동
# 3  약사명동  중앙로2가
# 4   영랑동    장사동

# %% [markdown]
# #### 서울 스타벅스

# %%
# 이번엔 서울에 있는 스타벅스를 뽑아냅니다.
df_seoul_starbucks = df_seoul_coffee[df_seoul_coffee.상호명.str.contains('스타벅스')]
df_seoul_starbucks.index = range(len(df_seoul_starbucks))
print('서울시 내 스타벅스 점포 수 :', len(df_seoul_starbucks))
df_seoul_starbucks.head()
# Out:
# 서울시 내 스타벅스 점포 수 : 488
#            상호명      지점명 상권업종대분류명 상권업종중분류명     상권업종소분류명   표준산업분류명    시도명  시군구명  \
# 0         스타벅스   동숭로아트점       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  서울특별시   종로구
# 1  스타벅스남부터미널2점  남부터미널2점       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  서울특별시   서초구
# 2         스타벅스      당산점       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  서울특별시  영등포구
# 3         스타벅스    가로수길점       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  서울특별시   강남구
# 4  스타벅스미아사거리역점  미아사거리역점       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  서울특별시   강북구
#
#    행정동명   법정동명
# 0   이화동    동숭동
# 1  서초3동    서초동
# 2  당산2동  당산동6가
# 3   신사동    신사동
# 4   송중동    미아동

# %%
df_seoul_coffee.상호명.value_counts()
# Out:
# 카페          414
# 이디야커피       367
# 스타벅스        331
# 투썸플레이스      165
# 커피빈         115
#            ...
# 다래사우나내매점      1
# imtcafe       1
# 카페티티카카        1
# 사주앤타로         1
# 타자도르          1
# Name: 상호명, Length: 15019, dtype: int64

# %% [markdown]
# #### 전국 이디야

# %%
df_ediya = df_coffee[df_coffee.상호명.str.contains('이디야커피')]
df_ediya.index = range(len(df_ediya))
print('전국 이디야 점포 수 :', len(df_ediya))
df_ediya.head()
# Out:
# 전국 이디야 점포 수 : 2060
#      상호명     지점명 상권업종대분류명 상권업종중분류명     상권업종소분류명   표준산업분류명  시도명 시군구명   행정동명  \
# 0  이디야커피  원주반곡동점       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  강원도  원주시  반곡관설동
# 1  이디야커피   춘천제일점       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  강원도  춘천시    강남동
# 2  이디야커피     흥업점       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  강원도  원주시    흥업면
# 3  이디야커피  속초동명항점       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  강원도  속초시    동명동
# 4  이디야커피   정동진역점       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  강원도  강릉시    강동면
#
#   법정동명
# 0  반곡동
# 1  온의동
# 2  흥업면
# 3  동명동
# 4  강동면

# %% [markdown]
# #### 서울 이디야

# %%
df_seoul_ediya = df_seoul_coffee[df_seoul_coffee.상호명.str.contains('이디야커피')]
df_seoul_ediya.index = range(len(df_seoul_ediya))
print('서울시 내 이디야 점포 수 :', len(df_seoul_ediya))
df_seoul_ediya.head()
# Out:
# 서울시 내 이디야 점포 수 : 419
#           상호명    지점명 상권업종대분류명 상권업종중분류명     상권업종소분류명   표준산업분류명    시도명  시군구명  \
# 0       이디야커피   신길역점       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  서울특별시  영등포구
# 1       이디야커피   라이프점       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  서울특별시  영등포구
# 2  이디야커피양재AT점  양재AT점       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  서울특별시   서초구
# 3       이디야커피    시흥점       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  서울특별시   금천구
# 4       이디야커피  개봉중앙점       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  서울특별시   구로구
#
#    행정동명  법정동명
# 0  신길1동   신길동
# 1   여의동  여의도동
# 2  양재2동   양재동
# 3  시흥2동   시흥동
# 4  개봉3동   개봉동

# %% [markdown]
# #### 전국 커피빈

# %%
df_coffeebean = df_coffee[df_coffee.상호명.str.contains('커피빈')]
df_coffeebean.index = range(len(df_coffeebean))
print('전국 커피빈 점포 수 :', len(df_coffeebean))
df_coffeebean.head()
# Out:
# 전국 커피빈 점포 수 : 290
#    상호명             지점명 상권업종대분류명 상권업종중분류명     상권업종소분류명   표준산업분류명  시도명 시군구명  \
# 0  커피빈             NaN       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  강원도  동해시
# 1  커피빈     코리아원주AK플라자점       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  강원도  원주시
# 2  커피빈    현대프리미엄아울렛김포점       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  경기도  김포시
# 3  커피빈  중동현대백화점U-PLEX점       음식   커피점/카페  커피전문점/카페/다방       NaN  경기도  부천시
# 4  커피빈   코리아중동위브더스테이트점       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  경기도  부천시
#
#   행정동명  법정동명
# 0  묵호동  묵호진동
# 1  단계동   단계동
# 2  고촌읍   고촌읍
# 3  NaN    중동
# 4  중2동    중동

# %% [markdown]
# #### 서울 커피빈

# %%
df_seoul_coffeebean = df_seoul_coffee[df_seoul_coffee.상호명.str.contains('커피빈')]
df_seoul_coffeebean.index = range(len(df_seoul_coffeebean))
print('서울시 내 커피빈 점포 수 :', len(df_seoul_coffeebean))
df_seoul_coffeebean.head()
# Out:
# 서울시 내 커피빈 점포 수 : 168
#            상호명           지점명 상권업종대분류명 상권업종중분류명     상권업종소분류명   표준산업분류명    시도명  \
# 0          커피빈   코리아대학로대명거리점       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  서울특별시
# 1  커피빈코리아낙성대역점      코리아낙성대역점       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  서울특별시
# 2          커피빈  코리아강남역랭기지타워점       음식   커피점/카페  커피전문점/카페/다방       NaN  서울특별시
# 3          커피빈      코리아청담성당점       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  서울특별시
# 4          커피빈      코리아청담에스점       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  서울특별시
#
#   시군구명  행정동명  법정동명
# 0  종로구   혜화동  명륜4가
# 1  관악구   행운동   봉천동
# 2  강남구  역삼1동   역삼동
# 3  강남구   청담동   청담동
# 4  강남구   청담동   청담동

# %% [markdown]
# #### 전국 투썸

# %%
df_2some = df_coffee[df_coffee.상호명.str.contains('투썸플레이스')]
df_2some.index = range(len(df_2some))
print('전국 투썸 점포 수 :', len(df_2some))
df_2some.head()
# Out:
# 전국 투썸 점포 수 : 1030
#       상호명     지점명 상권업종대분류명 상권업종중분류명     상권업종소분류명   표준산업분류명  시도명 시군구명  행정동명  \
# 0  투썸플레이스   춘천명동점       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  강원도  춘천시   조운동
# 1  투썸플레이스   강릉포남점       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  강원도  강릉시  포남1동
# 2  투썸플레이스   소양강댐점       음식   커피점/카페  커피전문점/카페/다방       NaN  강원도  춘천시   신북읍
# 3  투썸플레이스  용평리조트점       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  강원도  평창군  대관령면
# 4  투썸플레이스   철원와수점       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  강원도  철원군    서면
#
#    법정동명
# 0   조양동
# 1   포남동
# 2   신북읍
# 3  대관령면
# 4    서면

# %% [markdown]
# #### 서울 투썸

# %%
df_seoul_2some = df_seoul_coffee[df_seoul_coffee.상호명.str.contains('투썸플레이스')]
df_seoul_2some.index = range(len(df_seoul_2some))
print('서울시 내 투썸 점포 수 :', len(df_seoul_2some))
df_seoul_2some.head()
# Out:
# 서울시 내 투썸 점포 수 : 244
#              상호명                지점명 상권업종대분류명 상권업종중분류명     상권업종소분류명   표준산업분류명  \
# 0         투썸플레이스              서울타워점       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업
# 1  투썸플레이스서울대역중앙점            서울대역중앙점       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업
# 2         투썸플레이스  씨제이프레시웨이강남세브란스병원점       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업
# 3         투썸플레이스           LG광화문빌딩점       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업
# 4         투썸플레이스             가락시장역점       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업
#
#      시도명 시군구명   행정동명   법정동명
# 0  서울특별시  용산구  용산2가동  용산동2가
# 1  서울특별시  관악구    중앙동    봉천동
# 2  서울특별시  강남구   도곡1동    도곡동
# 3  서울특별시  종로구    사직동  신문로2가
# 4  서울특별시  송파구   가락본동    가락동

# %% [markdown]
# #### 전국 빽다방

# %%
df_bbaek = df_coffee[df_coffee.상호명.str.contains('빽다방')]
df_bbaek.index = range(len(df_bbaek))
print('전국 빽다방 점포 수 :', len(df_bbaek))
df_bbaek.head()
# Out:
# 전국 빽다방 점포 수 : 608
#         상호명       지점명 상권업종대분류명 상권업종중분류명     상권업종소분류명   표준산업분류명  시도명 시군구명 행정동명  \
# 0       빽다방  춘천석사CGV점       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  강원도  춘천시  석사동
# 1  빽다방동해천곡점     동해천곡점       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  강원도  동해시  천곡동
# 2       빽다방   원주중앙1호점       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  강원도  원주시  일산동
# 3       빽다방    삼척대학로점       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  강원도  삼척시  성내동
# 4       빽다방       NaN       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  강원도  원주시  일산동
#
#   법정동명
# 0  석사동
# 1  천곡동
# 2  일산동
# 3  당저동
# 4  일산동

# %% [markdown]
# #### 서울 빽다방

# %%
df_seoul_bbaek = df_seoul_coffee[df_seoul_coffee.상호명.str.contains('빽다방')]
df_seoul_bbaek.index = range(len(df_seoul_bbaek))
print('서울시 내 빽다방 점포 수 :', len(df_seoul_bbaek))
df_seoul_bbaek.head()
# Out:
# 서울시 내 빽다방 점포 수 : 126
#            상호명       지점명 상권업종대분류명 상권업종중분류명     상권업종소분류명   표준산업분류명    시도명 시군구명  \
# 0    빽다방공덕새창로점    공덕새창로점       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  서울특별시  마포구
# 1     빽다방서초우성점     서초우성점       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  서울특별시  서초구
# 2  빽다방중계은행사거리점  중계은행사거리점       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  서울특별시  노원구
# 3     빽다방성신여대점     성신여대점       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  서울특별시  성북구
# 4    빽다방신림역1호점    신림역1호점       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  서울특별시  관악구
#
#    행정동명   법정동명
# 0   도화동    도화동
# 1  서초2동    서초동
# 2  중계1동    중계동
# 3   동선동  동선동1가
# 4   서원동    신림동

# %% [markdown]
# #### 전국 할리스

# %%
df_hollys = df_coffee[df_coffee.상호명.str.contains('할리스커피')]
df_hollys.index = range(len(df_hollys))
print('전국 할리스 점포 수 :', len(df_hollys))
df_hollys.head()
# Out:
# 전국 할리스 점포 수 : 504
#           상호명        지점명 상권업종대분류명 상권업종중분류명     상권업종소분류명   표준산업분류명  시도명 시군구명  \
# 0       할리스커피        원주점       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  강원도  원주시
# 1       할리스커피        중앙점       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  강원도  원주시
# 2  할리스커피동해묵호점      동해묵호점       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  강원도  동해시
# 3    할리스커피강릉점        강릉점       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  강원도  강릉시
# 4       할리스커피  강릉휴게소인천방면       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  강원도  강릉시
#
#   행정동명 법정동명
# 0  단구동  단구동
# 1  중앙동  중앙동
# 2  천곡동  평릉동
# 3  중앙동  금학동
# 4  성산면  성산면

# %% [markdown]
# #### 서울 할리스

# %%
df_seoul_hollys = df_seoul_coffee[df_seoul_coffee.상호명.str.contains('할리스커피')]
df_seoul_hollys.index = range(len(df_seoul_hollys))
print('서울시 내 할리스 점포 수 :', len(df_seoul_hollys))
df_seoul_hollys.head()
# Out:
# 서울시 내 할리스 점포 수 : 127
#           상호명       지점명 상권업종대분류명 상권업종중분류명     상권업종소분류명   표준산업분류명    시도명 시군구명  \
# 0  할리스커피남부터미널       NaN       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  서울특별시  서초구
# 1   할리스커피마포역점      마포역점       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  서울특별시  마포구
# 2       할리스커피  목동예술인회관점       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  서울특별시  양천구
# 3       할리스커피  르네상스사거리점       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  서울특별시  강남구
# 4    할리스커피화양점       화양점       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  서울특별시  광진구
#
#    행정동명 법정동명
# 0  서초1동  서초동
# 1   용강동  도화동
# 2   목1동   목동
# 3  역삼2동  역삼동
# 4   화양동  화양동

# %% [markdown]
# #### 전국 메가커피

# %%
df_mega = df_coffee[df_coffee.상호명.str.contains('메가커피')]
df_mega.index = range(len(df_mega))
print('전국 메가커피 점포 수 :', len(df_mega))
df_mega.head()
# Out:
# 전국 메가커피 점포 수 : 445
#           상호명     지점명 상권업종대분류명 상권업종중분류명     상권업종소분류명   표준산업분류명  시도명 시군구명  \
# 0     메가커피인제점     인제점       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  강원도  인제군
# 1        메가커피    와수리점       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  강원도  철원군
# 2        메가커피  화천사창리점       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  강원도  화천군
# 3  메가커피철원문혜리점  철원문혜리점       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  강원도  철원군
# 4        메가커피   강릉포남점       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  강원도  강릉시
#
#    행정동명 법정동명
# 0   인제읍  인제읍
# 1    서면   서면
# 2   사내면  사내면
# 3   갈말읍  갈말읍
# 4  포남1동  포남동

# %% [markdown]
# #### 서울 메가커피

# %%
df_seoul_mega = df_seoul_coffee[df_seoul_coffee.상호명.str.contains('메가커피')]
df_seoul_mega.index = range(len(df_seoul_mega))
print('서울시 내 메가커피 점포 수 :', len(df_seoul_mega))
df_seoul_mega.head()
# Out:
# 서울시 내 메가커피 점포 수 : 82
#       상호명     지점명 상권업종대분류명 상권업종중분류명     상권업종소분류명   표준산업분류명    시도명  시군구명  행정동명  \
# 0  메가커피미아   수유시장점       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  서울특별시   강북구   미아동
# 1    메가커피   아차산역점       음식   커피점/카페  커피전문점/카페/다방       NaN  서울특별시   광진구  중곡4동
# 2    메가커피     NaN       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  서울특별시  동대문구   용신동
# 3    메가커피     NaN       음식   커피점/카페  커피전문점/카페/다방  비알콜 음료점업  서울특별시   금천구   가산동
# 4    메가커피  개봉사거리점       음식   커피점/카페  커피전문점/카페/다방       NaN  서울특별시   구로구  개봉1동
#
#   법정동명
# 0  미아동
# 1  중곡동
# 2  신설동
# 3  가산동
# 4  개봉동

# %% [markdown]
# ## 3. 커피전문점 별 비율 비교하기 (주요 브랜드 위주로)

# %% [markdown]
# 1. 스타벅스
# 2. 투썸플레이스
# 3. 이디야
# 4. 메가커피
# 5. 커피빈

# %% [markdown]
# **변수**
#
# - 전체 점포 : data
# - 전체/서울 커피전문점 : df_coffee / df_seoul_starbucks
#
#
#
# - 전체/서울 스타벅스 : df_starbucks / df_seoul_starbucks
# - 전체/서울 이디야 : df_ediya / df_seoul_ediya
# - 전체/서울 커피빈 : df_coffeebean / df_seoul_coffeebean
# - 전체/서울 투썸플레이스 : df_2some / df_seoul_2some
# - 전체/서울 빽다방 : df_bbaek / df_seoul_bbaek
# - 전체/서울 할리스 : df_hollys / df_seoul_hollys
# - 전체/서울 메가커피 : df_mega / df_seoul_mega

# %% [markdown]
# ### 1) 전체 커피전문점 내 주요 커피브랜드 입점 비율

# %%
## print("**** 전국 커피전문점중 주요 5대 커피브랜드 입점 비율 ****")
print("주요 5대 커피브랜드 전국 입점 비율 : %.3f%%")
print("1. 스타벅스 : %.3f%%" %(len(df_starbucks)/len(df_coffee)*100) )
print("2. 투썸플레이스 : %.3f%%" %(len(df_2some)/len(df_coffee)*100) )
print("3. 이디야 : %.3f%%" % (len(df_ediya)/len(df_coffee)*100))
print("4. 메가커피 : %.3f%%" %(len(df_mega)/len(df_coffee)*100) )
print("5. 커피빈 : %.3f%%" % (len(df_coffeebean)/len(df_coffee)*100))
# Out:
# 주요 5대 커피브랜드 전국 입점 비율 : %.3f%%
# 1. 스타벅스 : 1.418%
# 2. 투썸플레이스 : 0.945%
# 3. 이디야 : 1.891%
# 4. 메가커피 : 0.408%
# 5. 커피빈 : 0.266%

# %% [markdown]
# ### 2) 서울 커피전문점 내 주요 커피브랜드 입점 비율

# %%
print("스타벅스 : %.3f%%" % (len(df_seoul_starbucks)/len(df_seoul_coffee)*100) )
print("이디야 : %.3f%%" % (len(df_seoul_ediya)/len(df_seoul_coffee)*100) )
print("커피빈 : %.3f%%" % (len(df_seoul_coffeebean)/len(df_seoul_coffee)*100))
print("투썸플레이스 : %.3f%%" % (len(df_seoul_2some)/len(df_seoul_coffee)*100))
print("빽다방 : %.3f%%" %(len(df_seoul_bbaek)/len(df_seoul_coffee)*100) )
print("할리스 : %.3f%%" % (len(df_seoul_hollys)/len(df_seoul_coffee)*100))
print("메가커피 : %.3f%%" % (len(df_seoul_mega)/len(df_seoul_coffee)*100))
# Out:
# 스타벅스 : 2.343%
# 이디야 : 2.011%
# 커피빈 : 0.806%
# 투썸플레이스 : 1.171%
# 빽다방 : 0.605%
# 할리스 : 0.610%
# 메가커피 : 0.394%

# %% [markdown]
# ### 3) 각 커피브랜드별 서울 입점 비율

# %%
print("**** 주요 5대 커피브랜드별 서울 입점 비율 ****")
print("1. 스타벅스 : %.3f%%" %(len(df_seoul_starbucks)/len(df_starbucks)*100) )
print("2. 투썸플레이스 : %.3f%%" %(len(df_seoul_2some)/len(df_2some)*100) )
print("3. 이디야 : %.3f%%" %(len(df_seoul_ediya)/len(df_ediya)*100) )
print("4. 메가커피 : %.3f%%" % (len(df_seoul_mega)/len(df_mega)*100))
print("5. 커피빈 : %.3f%%" % (len(df_seoul_coffeebean)/len(df_coffeebean)*100))
# Out:
# **** 주요 5대 커피브랜드별 서울 입점 비율 ****
# 1. 스타벅스 : 31.586%
# 2. 투썸플레이스 : 23.689%
# 3. 이디야 : 20.340%
# 4. 메가커피 : 18.427%
# 5. 커피빈 : 57.931%

# %%
# 각 구별로 스타벅스가 얼마나 있는지 확인합니다.
starbucks_gu = df_seoul_starbucks.groupby('시군구명')['상호명'].count().to_frame().sort_values(by='상호명', ascending=False)
starbucks_gu = starbucks_gu.reset_index()
starbucks_gu = starbucks_gu.set_index('시군구명')
starbucks_gu
# Out:
#       상호명
# 시군구명
# 강남구    79
# 중구     43
# 서초구    41
# 송파구    33
# 종로구    31
# 영등포구   28
# 마포구    27
# 용산구    22
# 서대문구   19
# 광진구    18
# 강서구    17
# 성북구    15
# 강동구    13
# 노원구    12
# 양천구    12
# 관악구    11
# 금천구    11
# 동작구    11
# 구로구     9
# 동대문구    8
# 은평구     8
# 중랑구     7
# 성동구     6
# 강북구     5
# 도봉구     2

# %%
# 시각화를 위한 라이브러리를 불러옵니다.
import seaborn as sns
import matplotlib.pyplot as plt
import platform

from matplotlib import font_manager, rc
# %matplotlib inline

# %%
#### Windows10 사용자는 해당 코드가 필요없습니다!

# macos에서 사용가능한 한글 글꼴 확인 코드
[f.name for f in font_manager.fontManager.ttflist if 'Neo' in f.name]
# Out:
# []

# %%
## 운영체제별 글꼴 세팅

path = "c:/Windows/Fonts/malgun.ttf"
if platform.system() == 'Darwin':
    font_name = 'Apple SD Gothic Neo'
    rc('font', family='Apple SD Gothic Neo')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    font_name = font_manager.FontProperties(fname="/usr/share/fonts/nanumfont/NanumGothic.ttf")
    rc('font', family="NanumGothic")

# %%
# 주요 5대 커피브랜드 서울 입점 비율을 시각화합니다.
starbucks_r = len(df_seoul_starbucks)/len(df_starbucks)*100
some_r = len(df_seoul_2some)/len(df_2some)*100
ediya_r = len(df_seoul_ediya)/len(df_ediya)*100
mega_r = len(df_seoul_mega)/len(df_mega)*100
coffeebean_r = len(df_seoul_coffeebean)/len(df_coffeebean)*100
print(values)
# Out:
# [31.585760517799354, 23.689320388349515, 20.339805825242717, 18.426966292134832, 57.931034482758626]

# %%
import numpy as np
x = np.arange(5)
company = ['스타벅스', '투썸', '이디야','메가','커피빈']
values = [starbucks_r,some_r,ediya_r,mega_r,coffeebean_r]
colors = ['g','darkred','mediumblue','y','brown']

plt.bar(x, values, color = colors)
plt.xticks(x, company)

plt.show()
